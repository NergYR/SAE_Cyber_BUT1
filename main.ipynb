# %%
import scapy as sc
#print(f"\nL'interface par défaut utilisée pour l'émission et la réception des␣ ,→paquets est {sc.iface}.")
#print(f"\nLa table de routage utilisée est : \n {sc.route}.")
#print('\nLa passerelle par défaut est :', sc.route.route("0.0.0.0")[2])

# %% [markdown]
# 1. Ouvre le fichier McDiarmid.pcapng dans Wireshark et mettre une image de cette capture
# dans ton notebook avec le détail du 2ème paquet.
# ![Capture_ip_wire.PNG](data:image/png;base64,...)
# Voici la capture du 2e paquet de la conversation TCP ![image_2023-12-18_151231488.png](data:image/png;base64,...)
# ![image_2023-12-18_151256864.png](data:image/png;base64,...)
# ![Capture_ip_wire.PNG](data:image/png;base64,...![Capture_ip_wire.PNG](data:image/png;base64,...))
# on remarque ici que le message de bienvenue du serveur FTP est "Come over the dark side".

# %% [markdown]
# 2. Les informations vitales recherchées ont été transférées dans un fichier codé. En regardant
# la capture, précise quel protocole applicatif a été utilisé pour l'envoi de ce fichier. Pour la
# suite tu pourras t'aider de Wikipédia.
#
# On remarque dans la capture effectué que le protocole applicatif utilisé pour l'envoi de ce fichier est le protocole FTP :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Quel est l'adresse IP du client et du serveur
#
#  L'addresse IP du client est : 192.168.35.24 d'après la capture et l'adresse IP du serveur FTP est 192.168.35.235
# ![/content/Capture_ip_wire.PNG](data:image/png;base64)
# ![Capture_ip_wire.png](data:image/png;base64

# %% [markdown]
# 4. Le protocole pour le transport est le protocole TCP

# %% [markdown]
# 5. La bannière de bienvenue est :
# #########################################
# \ ##         Come over the dark side     ##
# #########################################

# %%
# Test

# %%
#Resr
